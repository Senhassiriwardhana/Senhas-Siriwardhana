# %%
#Quiz Game
print("==WELCOME TO THE GAME==")

#GET USER NAME
name = input("Enter your Name")
print(f"Hello{Name},Welcome To the quiz/n")

score = 0
#question 1
q1 = input("1.What is the capital Of the France")
if q1.strip().lower() == "Paris"
print("Correct!/n")

score +=1
else:
  print("wrong, Correct answer is Paris./n")


#question 2
q2 = input("1.What is the capital Of the Sri lanka")
if q2.strip().lower() == "Sri Jayawardhanapurakotte"
print("Correct!/n")

score +=1
else:
  print("wrong, Correct answer is Sri Jayawardhanapurakotte./n")

 #question 3
q3 = input("1.What is the Largest Country")
if q3.strip().lower() == "Russia"
print("Correct!/n")

score +=1
else:
  print("wrong, Correct answer is Russia./n")

 #question 4
q4 = input("1.What is the Largest Island")
if q4.strip().lower() == "Sri lanka"
print("Correct!/n")

score +=1
else:
  print("wrong, Correct answer is Sri lanka./n")

  #Final Score
  print(f"{Name},Your Final score is{score/4}")

  #Message based on Score
  if score = 3:
    print("Excellent")
  elif score = 2:
    print("Good")
  elif score = 1;
    print("Not bad,But work hard")
    else:
     print("Low Mark")
